# %% [markdown]
# (Chapter-1)=
# # Heading

# %%
import jupyterlab
print(jupyterlab.__version__)
# Out:
# 4.2.5

# %% [markdown]
# chapter 2<a class="anchor" id="chapter_2"></a>

# %% [markdown]
# go to [heading](chapter_2) now!
