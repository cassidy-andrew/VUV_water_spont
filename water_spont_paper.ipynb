# %% [markdown]
# # Spontaneously polarised crystalline water ice
#
# _Authors: Rachel James (1), Frank Pijpers (2), Lars Borchert (3), David Field (3), Andrew Cassidy* (3)_
#
# (1) Department of Earth and Environmental Sciences, The University of Manchester, Manchester, UK<br>
# (2) Korteweg - de Vries Institute for Mathematics, University of Amsterdam, Amsterdam, Netherlands<br>
# (3) Center for Interstellar Catalysis, Department of Physics and Astronomy, Aarhus University, Aarhus, Denmark<br>
#
# *corresponding author amc@phys.au.dk<br>

# %% [markdown]
# #### Python Imports

# %%
# Import necessary modules
import os
import math
import cmath
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator, MultipleLocator, FormatStrFormatter
from matplotlib.gridspec import GridSpec
from scipy.optimize import curve_fit
import scipy.constants as constants
import seaborn as sns
import sympy as sp
from sympy import symbols, diff
from collections import defaultdict
from IPython.display import Image, HTML, Markdown
import openpyxl
import xlrd
import glob
# %run define_functions.ipynb

print('Finished imports')
# Out:
# Finished imports

# %% [markdown]
# ### Abstract <a class="anchor" id="abstract"></a>
# We describe a novel aspect of the structure of the hexagonal phase of crystalline water ice, using vacuum-ultraviolet absorption spectroscopy as a diagnostic tool. The key result is that hexagonal ice ($I_h$), prepared from condensation of pure water vapour, displays net molecular orientation. This reflects order in the disposition of the protons in ice $I_h$ and our results require revision of the near century old conventional structure in which water molecular dipoles point in random directions in hexagonal ice. Orientation gives rise to spontaneous polarization and internal fields of $~4 \times 10^6\,$ V m$^{-1}$ in films of ice $I_h$ tens of nanometres thick, condensed on an insulating MgF$_2$ substrate. Data are in the form of Stark shifts in absorption spectra, with no free charges or external electric fields introduced in the experiment.

# %% [markdown]
# ### Introduction <a class="anchor" id="introduction"></a>
#
# Electric fields can change the chemical structure, electronic behaviour and motion of molecules.[1](#ref_1) The effect of these fields has become a new frontier in areas ranging from catalysis, across biology, and to the engineering of electronic devices. For example, in biology, effects are often based on the natural ability of enzymes to generate local electric fields around molecular structures to catalyse specific processes. In the present work, we report on the inherent ability of nanoscale films of crystalline hexagonal water ice to spontaneously achieve a structure by which dipoles orient and produce an electric field internal to the solid.
#
# Our results challenge the concept that solid crystalline water is always a proton disordered material. Hexagonal water ice, $I_h$, represents *“ordinary”* crystalline ice in our everyday experience. A central issue in the structure of ice $I_h$ is the presence or absence of molecular dipole ordering.[2](#ref_2),[3](#ref_3),[4](£ref_¤) In ice $I_h$, molecules are positioned on an hexagonal array of $O$ atoms with molecular dipoles directed along the $C2$ rotation axes, conventionally pointing in random directions giving no dipole order, following the Bernal-Fowler ice rules.[5](#ref_5) The spontaneous orientational order reported here, in crystalline ice, therefore represents a weak violation of the ice rules but  does not involve sufficient translation of H atoms to form Bjerrum defects. The dipole moment of water in the solid is sufficiently large, 3.0$\,$D[6](#ref_&),[7](#ref_7) to create substantial internal electric fields despite the minor degree of order.
#
# Spontaneous polarization in non-crystalline water ice, formed below 127.5$\,$K, is a known proposition. Onsager et al. observed that condensing samples of pure water ice at 78$\,$K, to form amorphous solid water (ASW), produced electrical effects.[8](#ref_8) Subsequent Kelvin probe measurements concurred, and reported weak fields permeating ASW, formed by condensation on substrates at $\leqq$125$\,$K.[6](#ref_6),[7](#ref_7),[9](#ref_9) These observations indicate a contribution from the presence of local fields of $>$10$^9$$\,$V m$^{-1}$, created through unbalanced dipoles in pores [6](#ref_6),[10](#ref_10) and sufficient to influence the hydrogen bond energy.[11](#ref_11),[12](#ref_12) Such fields can be recreated using molecular dynamics simulations.[13](#ref_13)
#
# Previous observations of polarized crystalline water ice, as here, have been associated with injection of ions into the ice at the ice-substrate boundary. For example, Ice *XI*, prepared from dilute KOH, has been suggested as ferroelectric in [14](#ref_14), though brought into doubt in [15](#ref_15). Violation of the ice rules has also been observed in water ice in hetero-epitaxial ice films. Sum-frequency generation (SFG) spectroscopy revealed spontaneous polarization,[16](#ref_16),[17](#ref_17) stabilized by the presence of hydronium (H$_3$O$^+$) ions at the interface with the ice film, where ions were formed through hole injection from a Pt(111) substrate. This leads to a strongly non-uniform field. Here by contrast, we use a substrate with a high band gap, MgF$_2$, from which we may assume at our low temperatures that there is no injection of ions and thus we maintain pure water ice.
#
# In the present work we report vacuum ultra-violet (VUV) absorption spectra for water ices condensed across a temperature range from 20$\,$K to 140$\,$K. This temperature range crosses the amorphous to crystalline phase transition for water ice at ~127.5$\,$K. Below the phase transition, the behaviour of VUV spectra concurs with what is known about the collapse of pores in films of ASW. Above the crystallisation temperature, films demonstrate an excitonic Stark effect,[18](#ref_18) with absorption wavelengths showing correlation with deposition temperature. We have previously demonstrated, for films of carbon monoxide, nitrous oxide and ammonia, that this Stark effect in VUV spectroscopy can be used to quantify the rate of change in the degree of polarisation with condensation temperature. Moreover this rate of change can be understood by a model for the spontelectric effect.[18](#ref_18) This model, introduced in more detail below, ascribes polarization to a metastable equilibrium established between water dipoles, which align with the intrinsic electric field that arises in condensed molecular films, and thermally induced disorder. In short, the spontelectric model describes spontaneous polarization as a homogeneous bulk effect. Hence, we report a metastable polarised phase of crystalline water ice.

# %% [markdown]
# ### Methods <a class="anchor" id="methods"></a>
#
# Films of pure water ice were condensed, from a partial pressure of $~$10$^{-7}$$\,$mbar, onto a cold MgF$_2$ substrate maintained at a chosen fixed temperature and acting as a VUV window, held inside a chamber with a base pressure <2 x 10$^{-8}$$\,$mbar. Deionised water was purified using multiple freeze-pump-thaw cycles prior to introduction to the vacuum measurement chamber, using a high precision variable leak valve attached to a tube of 6$\,$mm diameter that lay 25$\,$mm from the substrate.  Film thicknesses were quantified using a laser interferometer technique.[19](#ref_19) Note that a new film was laid down at each temperature and films were not heated or cooled before spectra were taken. Temperatures were measured using a Si-diode located close to the MgF$_2$ substrate and the temperature was controlled by heating the cryo finger via a resistive heater. Data were taken on the UV beamline on the ASTRID2 facility at Aarhus University, where the high stability of the VUV source allows for the very accurate spectral measurements necessary for this experiment. The low VUV flux did not induce chemistry or affect the physical structure of the film.[20](#ref_20) Values of absorbance, $ln(I_0(eV)/I(eV))$, *vs* eV were recorded, where $I_0(eV)$ is the transmitted intensity in the absence of a water film and $I(eV)$ is the transmitted intensity through the film and substrate.

# %% [markdown]
# ### Results <a class="anchor" id="results"></a>
#
# The VUV spectrum for a water ice film grown at 130$\,$K is shown in [Fig. 1](#figure_1)a. Earlier reports of VUV spectra of ice may be found in [21](#ref_21),[22](#ref_22),[23](#ref_23),[24](#ref_24). Representative spectra recorded of water ice films deposited at 125$\,$K – 140$\,$K, in the spectral region of interest, are shown in [Fig. 1](#figure_1)b. Three gaussians were fitted to each spectrum in [Fig. 1](#figure_1)a: a background peak to account for an absorption with a maximum above the MgF$_2$ cut-off at 10.78$\,$eV; a higher energy absorption peak around 8.65$\,$eV and a lower energy absorption peak around 7.98$\,$ eV. Our working hypothesis is that these two absorptions arise from the (1b$_1$)(4$_{a1}$) A $^1$B$_1$ $\leftarrow$ (1b$_1$)$^2$ X $^1$A$_1$ transition, blue-shifted relative to the equivalent gas phase transition at 7.4$\,$eV [25](#ref_25),[26](#ref_26), in hexagonal $I_h$ ice and cubic $I_c$ ice respectively. Thus we take the view that over the full temperature range, ice films are composed of both hexagonal and cubic ice moieties giving stacking disordered ice, $I_{sd}$.[27](#ref_27),[28](#ref_28),[29](#ref_29),[30](#ref_30) Assuming the same oscillator strength for both hexagonal and cubic ice, films are ~99% hexagonal and 1% cubic. Below, we demonstrate that the shift in peak positions with temperature arises from the Stark effect, with the macroscopic electric field intrinsic to the long-range ordered arrangement of dipoles within the condensed water ice film. Thus, our data refer to electric fields that are intrinsic to  hexagonal $I_h$ ice, with no contribution to these fields from cubic $I_c$ ice, since spontaneous fields are created through the concerted effect of at least 5 to 10 ML of material.[18](#ref_18) Thus $I_c$ ice is subjected to the electric field generated within $I_h$ ice, with no spontelectric field generated by $I_c$ ice alone. Positions for the peak centred at 8.65$\,$eV are shown as a function of sample deposition temperature in [Fig. 2](#figure_2). Both peak positions for crystalline films are listed in [Table 1](#table_1).
#
# Material is ASW for $T\, \leq \, $125$\,$ K and crystalline for $T\, \geq\,$ 127.5$\,$ K. Data for films deposited at 125$\,$K were observed to evolve with time, representing the phase change from crystalline to amorphous ice films. The spectral evolution at $T\,$ = 125$\,$K, and spectra for all temperatures are shown in the supporting materials.

# %% [markdown]
# #### Load data

# %%
###
### Find data files and fit all VUV spectra with Gaussians
###
# %run Fit_VUV_data_with_Gaussians.ipynb
# Out:
# All data fitted

# %% [markdown]
# #### Figure 1

# %%
### Plot Figure 1
#--------------------------------------------------------

###
### 1. We only want to compare films of approximately the same thickness and some are very close. We need to remove ambiguity
###

temperatures = np.array(obs_all_data.temp)
depositions = np.array(obs_all_data.dep)
peak1_positions = np.array(obs_all_data.peak1)
peak2_positions = np.array(obs_all_data.peak2)
peak1_err = np.array(obs_all_data.peak1_err)
peak2_err = np.array(obs_all_data.peak2_err)

#get list of required temps and deps
temp_dep_pos = list(zip(temperatures, depositions, peak1_positions, peak2_positions,peak1_err ,peak2_err ))

# Use a loop to remove the second thickest film in places where the thickness is very close
filtered_temp_dep_pos  =  []
for i in range(1, len(temp_dep_pos)):
    # If the current element is not the same as the previous element
    if temp_dep_pos[i][0] != temp_dep_pos[i-1][0]:
        # Add the previous element to the filtered list
        filtered_temp_dep_pos.append(temp_dep_pos[i-1])
# Add the last element
filtered_temp_dep_pos.append(temp_dep_pos[-1])

#send this filtered dataset to a dataframe
filtered_temp_dep_pos_df = pd.DataFrame(filtered_temp_dep_pos, columns=['Temperature_K', 'depositon#', '8_5eV_peak_eV', '8eV_peak_eV', '8_5eV_err', '8eV_err'])
df_selected = filtered_temp_dep_pos_df[['Temperature_K', '8_5eV_peak_eV', '8eV_peak_eV','8_5eV_err', '8eV_err']]
# Saving the selected columns to a CSV file
df_selected.to_csv('water_best_positions.csv', index=False)

# Save the data that corresponds to crystalline films, to a seperate text file 
df_spont = df_selected[df_selected['Temperature_K'] > 126]
df_spont.to_csv('water_spont_data.csv', index=False)

###
### 2. And finally, plot figure 1
###

peak1_values = filtered_temp_dep_pos_df['8_5eV_peak_eV']
peak2_values = filtered_temp_dep_pos_df['8eV_peak_eV']
filtered_temp = filtered_temp_dep_pos_df['Temperature_K']

#Get the csv data that stores xy data for each required temp and dep
best_spectra = []

#now extract the bkgd subtracted datacurves for filtered data sets
for fil_temp_dep_pos in filtered_temp_dep_pos:
    #   adjust for file naming - i.e. add  0.5 K to 127.5 and 137.5 K
    temperature_str = str(fil_temp_dep_pos[0])
    
    temperature_str = temperature_str[:-2]
    if len(temperature_str) == 2:
    # Add a zero to the beginning
        temperature_str = '0' + temperature_str
    if temperature_str[-1] == "7":
    # add "-5"
        temperature_str += "-5"
    #add text 
    temperature_str +="K_dep"+str(fil_temp_dep_pos[1])
    temperature_str  = temperature_str[:-1]+"csv"
    best_spectra.append(temperature_str)

# Define the colormap
cmap = plt.get_cmap('coolwarm')

# Define the offset for the waterfall plot
offset = 0

# define the figure
fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(6, 8), constrained_layout=True)

#top panel gives full spectrum at 130 K
full_spectrum = pd.read_csv(os.path.join(export_path, best_spectra[13])) #11th index is 125 K, 0th index would be 20 K
full_spectrum['photon_energy'] = WLtoE(full_spectrum.iloc[:, 0])
ax1.plot(full_spectrum['photon_energy'],full_spectrum['absorbance'], color = 'k', linestyle = '-')        
# set figure details
ax1.set_xlabel('photon energy (eV)', fontsize = 14)
ax1.set_xlim(5.65,10.5)
ax1.tick_params(axis='x', direction='inout', labelsize = 14, length=5, top = True)
ax1.tick_params(axis='x', which='minor', direction='out', length=2, top=True, bottom=True)
ax1.tick_params(axis='y', direction='inout', length=5, labelsize = 16, labelleft = True)
ax1.tick_params(axis='y', direction='inout', length=5, labelsize = 16, labelright = False, right = True)
ax1.set_ylabel('absorbance', fontsize = 14)

#bottom panel gives fit in region of interest
#Add the Gaussian fit for the first spectrum to the plot
first_spectrum = pd.read_csv(os.path.join(export_path, best_spectra[11])) #11th index is 125 K, 0th index would be 20 K
first_spectrum['photon_energy'] = WLtoE(first_spectrum.iloc[:, 0])
check_index = find_closest_match(first_spectrum, peak1_values,0, 0)[0]
offset = 0.05
first_spectrum['Normalized_Gauss_3'] = first_spectrum['Gauss_3'] - first_spectrum.iloc[find_closest_match(first_spectrum, peak1_values,0, 0)[0], 2]-offset
ax2.plot(first_spectrum['photon_energy'],first_spectrum['Normalized_Gauss_3'], color = 'k', linestyle = '--')

first_spectrum['Normalized_Gauss_1'] = first_spectrum['Gauss_1'] - first_spectrum.iloc[find_closest_match(first_spectrum, peak1_values,0, 0)[0], 2]-offset
ax2.plot(first_spectrum['photon_energy'],first_spectrum['Normalized_Gauss_1'], color = 'k', linestyle = '-.')

first_spectrum['Normalized_Gauss_2'] = first_spectrum['Gauss_2'] - first_spectrum.iloc[find_closest_match(first_spectrum, peak1_values,0, 0)[0], 2]-offset
ax2.plot(first_spectrum['photon_energy'],first_spectrum['Normalized_Gauss_2'], color = 'k', linestyle = ':')

first_spectrum['Normalized_Gauss_4'] = first_spectrum['Gauss_4'] - first_spectrum.iloc[find_closest_match(first_spectrum, peak1_values,0, 0)[0], 2]-offset
ax2.plot(first_spectrum['photon_energy'],first_spectrum['Normalized_Gauss_4'], color = 'k')

first_spectrum['Normalized_Gauss_fit'] = first_spectrum['Gauss_fit'] - first_spectrum.iloc[find_closest_match(first_spectrum, peak1_values,0, 0)[0], 2]
ax2.plot(first_spectrum['photon_energy'], first_spectrum['Normalized_Gauss_fit'], color='red', linestyle='--')#,  alpha=0.3)

offset = 0
#get each curve ready for the plot
for i, file in enumerate (sorted(best_spectra[11:])): 
    # Construct the full file path
    file_path = os.path.join(export_path, file)    
    # Read the csv file into a dataframe
    df = pd.read_csv(file_path)    
    #Convert the nm values in eV
    df['photon_energy'] = WLtoE(df.iloc[:, 0])  
    i = i+11
    # Plot the first two columns of the dataframe and add a point for the peak maximum    
    peak_energy = find_closest_match(df, peak1_values, i, offset) #find absorbance at top of peak 1
    ax2.plot(peak1_values[i], offset, 'ko') 
    ax2.plot(peak2_values[i], find_closest_match(df, peak2_values,i, offset)[2]+offset-(find_closest_match(df, peak1_values,i, offset)[2]), 'r^')     
    absorbance = df['absorbance']  + offset  #add the offset to the absorbance column for plotting
    df['Normalized Absorbance'] = absorbance - df.iloc[find_closest_match(df, peak1_values,i, offset)[0], 2]
    legend_label =str(filtered_temp[i])
    legend_label=legend_label[:-2]+' K'
    ax2.plot(df['photon_energy'], df['Normalized Absorbance'], label=legend_label, color=cmap((i-11) / len(best_spectra[11:])))
    ax2.text(10.1, df['Normalized Absorbance'].max()+0.0,legend_label,color=cmap((i-11) / len(best_spectra[11:])))
    # Increase the offset
    offset += 0.25

# set figure details
ax2.set_xlabel('photon energy (eV)', fontsize = 14)
ax2.set_xlim(7.0,10.5)
ax2.tick_params(axis='x', direction='inout', labelsize = 14, length=5, top = True)
ax2.minorticks_on()
ax2.tick_params(axis='x', which='minor', direction='out', length=2, top=True, bottom=True)

ax2.tick_params(axis='y', direction='inout', length=5, labelsize = 16, labelleft = False)
ax2.set_ylabel('absorbance', fontsize = 14)

#adjust the y-ticks so that 0 is at 0
yticks = np.array([0,1,2]) #np.array([0,1,2,3,4,5,6])
ax2.set_yticks(first_spectrum['Normalized_Gauss_fit'].min()+yticks, yticks)
ax2.set_ylim(first_spectrum['Normalized_Gauss_4'].min(),1.4)

# Create a twin y-axis
ax2_top = ax2.twinx()
# Label the secondary y and x -axes
ax2_top.set_yticks(first_spectrum['Normalized_Gauss_fit'].min()+yticks, yticks)
ax2_top.tick_params(axis='y', direction='inout', labelsize = 18, length=5,labelright=False)
ax2_top.set_ylim(first_spectrum['Normalized_Gauss_4'].min(),5)

#plt.legend()
fig.text(0.01, 1.005, '(a)', fontsize=14, va='top', ha='left')
fig.text(0.01, 0.51, '(b)', fontsize=14, va='top', ha='left')

# Save the figure as a PNG file
fig.savefig('Figure_1.png',dpi = 600, bbox_inches='tight' , format='png')
fig.savefig('Figure_1.svg',dpi = 600, bbox_inches='tight' , format='svg')

plt.show()

# %% [markdown]
# **Figure 1**<a class="anchor" id="figure_1"></a>: _Absorption spectra of an $\sim$8$\,$nm ($\sim$30$\,$ML) water ice film grown at 130$\,$ K. b) Spectra of $\sim$8$\,$nm ($\sim$30$\,$ML) water ice films grown between T = 125$\,$K and 140$\,$K. Spectra are displaced on the vertical axis and all possess a maximum absorbance of $\sim$0.6. Transitions centred around the high energy (black circles) and low energy (red triangles) are discussed in the text. The dashed lines show the Gaussian fits to the spectrum at 125$\,$K, with the resulting fit to the data shown in dashed red beneath this spectrum as a typical example._

# %% [markdown]
# #### Figure 2

# %%
###
### Figure 2
### ------------------

fig, ax1 = plt.subplots(figsize=(6,4))

ax1.errorbar(filtered_temp_dep_pos_df['Temperature_K'][0:], filtered_temp_dep_pos_df['8_5eV_peak_eV'][0:], yerr=filtered_temp_dep_pos_df['8_5eV_err'][0:], fmt='o', color='black', label='8.5 eV')
ax1.set_xlabel('temperature (K)', fontsize=16)
ax1.set_ylabel('peak position (eV)', fontsize=16)
ax1.yaxis.set_tick_params(right=True, labelright=False)
ax1.tick_params(axis='y', which='both', length=5, labelsize=14, direction='inout')
ax1.xaxis.set_ticks_position('both')
ax1.tick_params(axis='x', which='both', length=5, labelsize=14, direction='inout')

# Save the figure as a PNG file
fig.savefig('Figure_2.png',dpi = 600, bbox_inches='tight' ,format='png')
fig.savefig('Figure_2.svg',dpi = 600, bbox_inches='tight', format='svg')

# Show the plot
plt.show()

# %% [markdown]
# **Figure 2**<a class="anchor" id="figure_2"></a>: _Peak positions for the higher energy peak, attributed to $I_h$ ice, marked with black dots in [Figure 1](#figure_1). Data indicate a phase change between 125$\,$K and 127.5$\,$K. Errors, marked as vertical lines, are 1$\,$SD on the Gaussian fit and amount to systematic errors of up to 3.4$\,$meV and 7$\,$meV for the higher and lower energy peaks respectively._

# %% [markdown]
# ### Data analysis <a class="anchor" id="data_analysis"></a>
#
# For $I_{sd}$ with $T\, \geq \,$127.5$\,$K, the variation of transition energies with temperature, shown in [Fig. 2](#figure_2) and columns 2&3 in [Table 1](#table_1), may be ascribed to temperature dependent Stark effects.[18](#ref_18) The origin of the electric field responsible for the shift in the energy of the excitations, lies in the spontaneous orientation of dipoles and relates directly to the spontaneous partial ordering of protons in $I_h$ ice. Similar shifts in energy to those in [Figs. 1](#figure_1) & [2](#figure_2) have been observed in VUV absorption spectra of CO, nitrous oxide, ammonia and methanol and arise through the temperature dependence of the spontaneously created electric field - the *"spontelectric field"*.[18](#ref_18) We show below that a well-established model for the spontelectric effect, coupled with a simple electrostatic model involving the influence of the spontelectric field on the exciton, reproduces these shifts for T$\geq$127.5$\,$K for both the higher and lower energy features in [Fig. 1](#figure_1) and [Table 1](table_1). We use these data to give a quantitative estimate of the degree of orientational order and associated electric fields in the dominant $I_h$ component of the ice films.
#
# The spontelectric field, $E_{sp}$, acts on excitons, specifically Wannier-Mott electron-hole pairs, created in the A-state in the lattice of $I_{sd}$. If the ice is formed at higher temperature, say, the strength of the spontelectric field, $E_{sp}$, is lower and holds the hole and electron less far apart. This in turn causes the energy of the transition to decrease and is observed as the absorption peak red shifting. In the hypothetical absence of any intrinsic electric field in the ice film, the speration between the charge and hole within the exciton after excitation is represented by $r$. Dipoles orient at all temperatures for crystalline ice, and the resulting intrinsic electric fields produce  Coulombic effects that yield a Stark energy shift in the observed energy of the excitation. We describe this energy shift as $\delta$, and it is given by  $2 E_{sp}$ times the physical displacement, $\Delta r$, from the unperturbed separation, $r$, where [18](#ref_18),[20](#ref_20)
#
# [Eqn. 1]<a class="anchor" id="equation_1"></a>
# \begin{align}
# \mathrm{(1)} \quad  \Delta r = r [ ( 1 - 2 E_{sp} \epsilon r^2 ) ^ {-1/2}  - 1]
# \end{align}
#
# with $\epsilon$ as the relative permittivity of the medium, reported as 1.716.[31](#ref_31) The spontelectric field, $E_{sp}$, is a positive quantity since the molecules are on average weakly oriented such that the O-atom points towards the film surface, giving a negative surface potential.[9](#ref_9),[13](#ref_13)  Using [Equation 1](#equation_2), the strength of the intrinsic electric field may be expressed in terms of the energy shift observed in spectra, $\delta$, as a solution of the equation:
#
# [Eqn. 2]<a class="anchor" id="equation_2"></a>
# \begin{align}
# \mathrm{(2)} \quad \frac{\delta }  { 2r[(1-2E_{sp}\epsilon r^2 ) ^{-1/2} -1]  } -  E_{sp} = 0
# \end{align}
#
# from which, by squaring both sides and solving the resulting cubic in $E_{sp}$, it follows that:
#
# [Eqn. 3]<a class="anchor" id="equation_3"></a>
# \begin{align}
# \mathrm{(3)} \quad E_{sp} = - \frac{\delta}{3r} +  \left( \frac {\delta }{3 r} \right) \left[ 1 + \frac{6}{ \delta \epsilon r} \right]^{\frac{1}{2}} \cos \left[ \frac{1}{3} \arccos \left(  \frac {1 - \frac{9}{2\delta \epsilon r} } {\left[1 + \frac {6}{\delta \epsilon r}  \right] ^ { \frac {3}{2}}} \right) + \frac {2 \pi k}{3} \right]
# \end{align}
#
# with k$\,$=$\,$0, 1, 2. Only k$\,$=$\,$0 gives a positive root, with k$\,$=$\,$1 giving an unphysical negative value of $E_{sp}$ and k$\,$=$\,$2 no longer satisfying equation (2). This arises from the sign ambiguity introduced by squaring.
#
# Given values of r and $\delta$, the latter as a function of temperature, and shown in [Fig. 3](#figure_3), [Eqn. 3](#equation_3) enables the evaluation of the change of $E_{sp}$ with deposition temperature. Values of $\delta$ require knowledge of the shift in absorption energy relative to a hypothetical limiting value in absence of any intrinsoc electric field in the ice film, $E_0$. Here, we constrain $E_0$, such that the absorption peak position occurs at the limit of an infinitely thin film.
#
# The evaluation of $E_{sp}$ and degrees of orientation *vs* T represents an ill-posed problem, whose solution is to appeal to additional knowledge, so-called regularization. This is achieved using a well-established mean-field model of the spontelectric effect, which describes how $E_{sp}$ changes with temperature.[18](#ref_18) Thus we seek values of $\delta$, via $E_0$ and r, which simultaneously satisfy both [Eqn. 3](#equation_3) and the mean-field model for spontelectrics, which we now briefly describe.

# %% [markdown]
# As a crystalline layer of water ice accumulates during deposition, incoming molecular dipoles tend spontaneously to orient as they settle into the film. Spontaneous dipole orientation creates a surface potential and an electric field in the film, noting the absence of any free charge. The resulting spatially averaged degree of dipole orientation is given by the ratio of the average net component of the dipole moment in the direction $z$, perpendicular to the plane of the film, relative to the total dipole moment of the species in the solid state, that is $<\mu_z>/\mu$, henceforth $m$.  The magnitude of $m$ depends on the temperature of deposition, $T$, *i.e.*, the temperature of the surface. Dipole orientation is a bulk phenomenon and our analysis is therefore restricted to the $I_h$ component of the film, as mentioned above. The mean-field Hamiltonian, $\mathfrak{E}$, for the system is characterized by feedback, since $m$ itself depends on the interaction of the molecular dipole with the field, which itself depends on $m$. We write:
#
# [Eqn. 4]<a class="anchor" id="equation_4"></a>
# \begin{align}
# \mathrm{(4)} \quad \mathfrak{E} = \mu E_z = \mu \{E_s[ 1 +  \zeta m ^2] - E_A m\}
# \end{align}
#
# where $\mu$ is the dipole moment of water in the solid state[6](#ref_6),[7](#ref_7) and $E_z$ is the mean local field in the $z$-direction. In [Eqn. 4](#equation_4), the parameter $E_S$ represents polarization, dispersion and both covalent and coulombic interactions within the ice, including hydrogen bonding. The term $\mu E_S \zeta m^2$ embodies the reluctance of molecules to rotate against one another, which is a determining trait in this strongly hydrogen bonded system. The term $E_Am$ gives the value of the spontelectric field in the bulk of the ice. $E_S$ and $\zeta$ are free parameters to be determined by fitting to experimental data. Analysis [32](#ref_32) shows that the model requires that $E_A = 4\pi \mu / \Omega$ where $\Omega$ = 17.35$\,$Å$^3$ is the molecular volume of water molecules in ice,[33](#ref_33) yielding $E_A$ = -6.514$\,\times \,$10$^{10}$$\,$Vm$^{-1}$. The temperature of the substrate induces disored into the dipole orientation, and this is modeled using the Langevin relationship. Combining [Eqn. 4](#equation_4) with the standard Langevin relationship [34](#ref_34) yields:
#
# [Eqn. 5]<a class="anchor" id="equation_5"></a>
# \begin{align}
# \mathrm{(5)} \quad f(T,m) = m = \coth \left\{ \frac{ \mu [E_S [1 + \zeta m^2 ] - E_A m] } { T } \right\} - \left\{ \frac {\mu[E_S [1 + \zeta m^2 ] - E_A m } { T } \right\} ^{-1}
# \end{align}
#
# The task is therefore to find $m$ and the corresponding spontelectric field, $E_sp$ = $E_A m$, as a function of temperature. Thus, the two means of solving for $E_{sp}$, namely *via* the spontelectric model contained in [Eqn. 5](#equation_5) and *via* the exciton moedl contained by [Eqn. 3](#equation_3), provide for a regularized least squares approach. Values of $E_S$ and $\zeta$ are found by fitting [Eqn. 5](#equation_5), so that [Eqn. 3](#equation_3) is simultaneously satisfied according to a least squares criterion for any chosen exciton size $r$ and limiting value of transition energy, $E_0$. In order to facilitate this we employ the linear inverse form of the Langevin function.[35](#ref_35),[36](#ref_36) The parameter $E_A$ is also allowed to vary since both $\mu$ and $\Omega$ have associated uncertainties, but we find that $E_A$ becomes -6.5144$\,\times \,$10$^{10}$$\,$Vm$^{-1}$, remaining very close to the model value. The form of the [Eqns 3](#equation_3) to [5](#equation_5) is such that values of $r$ and $E_0$, and thus $\delta$, cannot be established independently. However, $E_0$ is constrained, first by observations, such that $E_0$ is lower in energy than $E$ and such that $\delta$ ([Fig. 3](#figure_3)) is equal for both the high energy and low energy transitions, and also by regularization using the spontelectric model. Only values of $\delta$ that allow the spontelectric model to recreate a monotonic change with temperature are permissible.
#
# These constraints and numerical experiments show that $E_0$ lies at 8.475$\,$eV for the higher energy line and 7.818$\,$eV for the lower energy line. The corresponding values of $\delta$ are shown in [Fig. 3](#figure_3) and the resulting fits are shown in [Fig. 4](#figure_4), with values from the exciton model and the spontelectric model listed in [TABLE 1](#table_1). Values of $r$, which is the most influential parameter in this context, are restricted to 9.75$\pm$0.25$\,$nm, a range which gives the best fit between the exciton model and the spontelectric model, see [Fig. 4b](#figure_4). The exciton size is therefore found to be much greater than the molecular diameter (0.32$\,$nm), consistent with a Wannier-Mott exciton. Associated values of parameters in the spontelectric model are $E_A$ = -6.5144$\,\times \,$10$^{10}$$\,$Vm$^{-1}$ (see above), $E_S$ = 1.8975$\,\times \,$10$^6$$\,$Vm$^{-1}$, $\zeta$ = 2.8944 x 10$^8$. The degree of orientation, $m$, varies weakly over the temperature range between 127.5$\,$K and 140$\,$K and falls between -6.12$\,\times \,$10$^{-5}$ and -5.87$\,\times \,$10$^{-5}$. Note that these values, and the value of $E_A$, are negative, due to the direction of orientation of the water molecules.
#
# Values of $m$ are very small, reflecting a rigid structure, commensurate with a strongly hydrogen bonded system. Very low values of $m$ nevertheless represent significant bound charge on the surface of the polarized ice, resulting from the high dipole moment of water moieties in ice and the small molecular volume of water. These together yield the large quoted value of $E_A$ and give fields, $E_{sp}$ =  $mE_A$, of the order of 6$\,\times \,$10$^{-5}$$\,\times \,$6.514$\,\times \,$ 10$^{10}$$\,$Vm$^{-1}$ corresponding to 1.30$\,$mV per ML. Thus the surface of the 30$\,$ML films studied here take on a negative potential of typically 39$\,$mV or 0.039$\,$Cm$^{-2}$.

# %% [markdown]
# #### Figure 3

# %%
###
### Figure 3
###

# Find the data
filename='water_spont_data' 
df = pd.read_csv(filename+'.csv', header=(0))

l0_eV_lower= 7.818149 # lambda_0 in eV      
l0_eV_higher = 8.475402 # lambda_0 in eV  
    
xdataraw_higher = (df.iloc[:,0]) #Temperature K
ydataraw_higher = (df.iloc[:,1]) #peak position eV

xdataraw_lower = (df.iloc[:,0]) #Temperature K
ydataraw_lower = (df.iloc[:,2]) #peak position eV

# calculate the energy difference, sigma, between lambda max (peak positions at each Tdep) and Lambda0 in eV:
DE_eV_higher=ydataraw_higher-l0_eV_higher  
DE_eV_lower=ydataraw_lower-l0_eV_lower 

#convert to atomic units
T=xdataraw_higher*3.16683e-6
DE_higher=DE_eV_higher*0.036749405469679
DE_lower=DE_eV_lower*0.036749405469679

### And make the figure
### --------

fig, ax1 = plt.subplots(figsize=(6,4))

ax1.errorbar(xdataraw_higher, DE_eV_higher, yerr = df['8_5eV_err'], fmt = 'o', color = 'black', label='8.65 eV', capsize=2)
ax1.errorbar(xdataraw_lower+0.2, DE_eV_lower, yerr = df['8eV_err'],fmt = 'v', color = 'red', label='7.98 eV', capsize=2)
ax1.set_xlabel('temperature (K)',  fontsize=18)
ax1.set_ylabel(r'energy shift, $\delta$ (eV)',  fontsize=18)
ax1.tick_params(axis='both', which='both', length=5, labelsize=16, direction='inout')
ax1.xaxis.set_ticks_position('both')
ax1.tick_params(axis='x', which='both', direction='inout')
ax1.yaxis.set_tick_params(right=True, labelright=False)
ax1.tick_params(axis='y', which='both', direction='inout')

plt.tight_layout()
plt.savefig('Figure_3.png', dpi = 600, bbox_inches='tight',format='png')
plt.savefig('Figure_3.svg',dpi = 600, bbox_inches='tight',format='svg')
# Show the plot
plt.show()

# %% [markdown]
# **Figure 3**<a class="anchor" id="figure_3"></a>: _Energy shifts, $\delta$, in the higher energy peaks (black circles) and lower energy peaks (red triangles) as a function of deposition temperature, T, for T$\geq$127.5$\,$K, relative to a zero, $E_0$, the peak position in the limit of an infinitely thin film, see text. The large uncertainty in $\delta$ for 140$\,$K for the lower energy transition (red), is estimated from the Gaussian fit and stems from the experimental problem that material is continually evaporating at 140$\,$K and that this spectral feature is $\sim$1$\,$% of the higher energy feature (see [Fig. 1](#figure_1))._

# %% [markdown]
# #### Figure 4

# %%
###
### Figure 4
###

r_nm = (9.5, 9.75, 10.0)  #vary the value of radius in size of exciton

# Specify the directory
dir_path = 'observed_data'

# Check if the directory exists
if os.path.exists(dir_path):
    # Use glob to match the pattern ‘*’ (all files)
    files = glob.glob(f'{dir_path}/*')
    
    # Use os.remove() to remove each file
    for f in files:
        os.remove(f)
    print("All files in 'observed_data' have been deleted.\n\n")
else:
    print("The directory 'observed_data' does not exist.\n\n")

# Create a single plot with data from all dataframes
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(nrows=3, ncols=2, figsize=(5, 7), sharex='col')
fig.subplots_adjust(wspace=0.05, hspace=0.01)

#first get the fit for the higher energy peak
DE = DE_higher
DE_eV = DE_eV_higher
xdataraw = xdataraw_higher   
which_peak = '8_6' 

#Define constants from the literature
eps = 1.70712 
density = 1
mu_0_Debye = 3 # solid state dipole moment since this is known for water 
IceMu = Solid_phase_dipole(density)*2.541746
Omega_SI = 17.35e-30 # volume in m**3 from saga et al. 
Omega = Omega_SI*18897259886**3 # convert volume to au

for i in r_nm:
    r_0 = i*18.897259886 #convert radius_nm to 
    #print('radius in au ',r_0)
    check = calc_Esp(r_0,DE)

data_files = glob.glob('observed_data/8***spont.csv')

#Need to have ordered sorting after glob operation:
def extract_middle_number(filename):
    part = filename.split("_", 3)[3]
    num = re.match(r"([0-9]+(?:\.[0-9]+)?)", part).group(1)    
    return float(num)

# Reorder: largest, smallest, middle
def reorder_three(data_files):
    
    nums = [(f, extract_middle_number(f)) for f in data_files]
    nums_sorted = sorted(nums, key=lambda x: x[1], reverse=True)
    largest = nums_sorted[0][0]
    smallest = nums_sorted[-1][0]
    middle  = nums_sorted[1][0]

    return [largest, smallest, middle]

data_files = reorder_three(data_files)

spont_fit1_min = pd.read_csv(data_files[0],  header = (0))
spont_fit1_max = pd.read_csv(data_files[1],  header = (0))
spont_fit1_best = pd.read_csv(data_files[2],  header = (0))

##plot the middle two panels
        
ax3.set_xlim(125.5, 142)
#axa.set_ylim(ymin, ymax)
ax3.plot(spont_fit1_min['Temperature'], spont_fit1_min['Observed_field'], 'k.',  label='exciton model')
ax3.plot(spont_fit1_max['Temperature'], spont_fit1_max['Observed_field'], 'k.',  label='exciton model')
ax3.plot(spont_fit1_best['Temperature'], spont_fit1_best['Observed_field'], 'ko',  label='exciton model')

ax3.plot(spont_fit1_min['Temperature'], spont_fit1_min['Calc_field'], 'r', alpha = 0.2, label='spontelectric model')
ax3.plot(spont_fit1_max['Temperature'], spont_fit1_max['Calc_field'], 'r', alpha = 0.2, label='spontelectric model')
ax3.fill_between(spont_fit1_min['Temperature'], spont_fit1_min['Calc_field'], spont_fit1_max['Calc_field'], color='grey', alpha=0.2)
ax3.plot(spont_fit1_best['Temperature'], spont_fit1_best['Calc_field'], 'r', label='spontelectric model')

ax3.text(spont_fit1_min['Temperature'].iloc[0]+1, spont_fit1_min['Calc_field'].iloc[0], 'r = '+str(r_nm[0])+' nm', color='black', fontsize=9, ha='left', va = 'bottom')
ax3.text(spont_fit1_max['Temperature'].iloc[0]+1, spont_fit1_max['Calc_field'].iloc[1], 'r = '+str(r_nm[2])+' nm', color='black', fontsize=9, ha='left', va = 'top')
ax3.text(spont_fit1_best['Temperature'].iloc[0]+1, spont_fit1_best['Calc_field'].iloc[0], 'r = '+str(r_nm[1])+' nm', color='black', fontsize=9, ha='left', va = 'bottom')

#ax3.set_xlabel('Temperature / K', fontsize=16, fontname='garamond')
ax3.xaxis.set_ticks_position('both')
ax3.tick_params(axis='x', which='both', length=5,  labelsize = 10, direction='inout')
ax3.xaxis.set_minor_locator(MultipleLocator(1))
ax3.tick_params(axis='x', which='minor', length=2, labelsize=0)  
#ax3.set_ylabel('Electric Field / Vm$^{-1}$', fontsize=16, fontname='garamond')
ax3.tick_params(axis='y', which='both', length=5,  labelsize = 10, direction='inout')
ax3.yaxis.set_tick_params(right=True, labelright=False)
#axa.legend(loc=0, fontsize=14, framealpha=0)
        
ax4.set_xlim(125.5, 142)
#axb.set_ylim(ymin_mu, ymax_mu)
ax4.plot(spont_fit1_min['Temperature'], spont_fit1_min['y'], 'k.',  label='exciton model')
ax4.plot(spont_fit1_max['Temperature'], spont_fit1_max['y'], 'k.',  label='exciton model')
ax4.plot(spont_fit1_best['Temperature'], spont_fit1_best['y'], 'ko',  label='exciton model')

ax4.plot(spont_fit1_min['Temperature'], spont_fit1_min['calc_y'], 'r', alpha = 0.2,label='spontelectric model')
ax4.plot(spont_fit1_max['Temperature'], spont_fit1_max['calc_y'], 'r', alpha = 0.2, label='spontelectric model')
ax4.fill_between(spont_fit1_min['Temperature'], spont_fit1_min['calc_y'], spont_fit1_max['calc_y'], color='grey', alpha=0.2)
ax4.plot(spont_fit1_best['Temperature'], spont_fit1_best['calc_y'], 'r', label='spontelectric model')

ax4.text(spont_fit1_min['Temperature'].iloc[0]+1, spont_fit1_min['calc_y'].iloc[0], 'r = '+str(r_nm[0])+' nm', color='black', fontsize=9, ha='left', va = 'top')
ax4.text(spont_fit1_max['Temperature'].iloc[0]+1, spont_fit1_max['calc_y'].iloc[1], 'r = '+str(r_nm[2])+' nm', color='black', fontsize=9, ha='left', va = 'bottom')
ax4.text(spont_fit1_best['Temperature'].iloc[0]+1, spont_fit1_best['calc_y'].iloc[0], 'r = '+str(r_nm[1])+' nm', color='black', fontsize=9, ha='left', va = 'top')

ax4.xaxis.set_ticks_position('both')
#ax4.set_xlabel('Temperature / K', fontsize=16, fontname='garamond')
ax4.tick_params(axis='x', which='both', length=5,  labelsize = 10, direction='inout')
ax4.xaxis.set_minor_locator(MultipleLocator(1))
ax4.tick_params(axis='x', which='minor', length=2, labelsize=0)  
ax4.yaxis.set_label_position("right")
#ax4.set_ylabel(r'Dipole orientation / $\mu_Z/\mu$', fontsize=16, fontname='garamond')
ax4.tick_params(axis='y', which='both', length=5,  labelsize = 10, direction='inout')
ax4.yaxis.set_tick_params(right=True, labelleft = False, labelright=True)

PlotSpontelData_paper(spont_fit1_best['Temperature'], spont_fit1_best['sigma_T'], spont_fit1_best['Calc_field'], spont_fit1_best['Observed_field'], spont_fit1_best['calc_y'], spont_fit1_best['y'], spont_fit1_best['sigma_y'], ax1, ax2)

###
### then use the same outcome to produce a graph for lower energy peak
###

DE = DE_lower
DE_eV = DE_eV_lower
xdataraw = xdataraw_lower
which_peak = '7_9'

# Enter initial guesses
folder_path = "observed_data"
use_parameters  = os.path.join(folder_path, '8_6_'+ str(r_nm[1]) + '_parameters.csv')
spont_para_best = pd.read_csv(use_parameters,  header = (0))
r_nm = r_nm[1] #because the best result is always the second entry here

Guess_E_S_Vm = spont_para_best['E_s'].values[0] #start_valu #2831269.909e6 #2.5441e6 # in V/m
Guess_E_A_Vm = spont_para_best['E_a'].values[0] # in V/m
Guess_zeta = spont_para_best['zeta'].values[0] #1.31878e8

#convert to au
r_au = r_nm*18.897259886 #convert radius_nm to au139.6764#
E_S_au = Guess_E_S_Vm/5.1422e+11
E_A_au = Guess_E_A_Vm/5.1422e+11 

# Get observed values for a starting value of r in au
Observed_field = Observed_Esp(r_au, DE_lower)

Observed_alignment = []
for i in Observed_field:
    Observed_alignment = np.append(Observed_alignment,i/Guess_E_A_Vm)

#store these outputs in dataframes
SpontelData = pd.DataFrame(columns=['weight', 'y', 'sigma_y', 'calc_y','Temperature', 'sigma_T', 'Observed_field','Calc_field'])
SpontelData['Observed_field'] = (Observed_field)
SpontelData['y'] = (Observed_alignment)
SpontelData['sigma_y'] = abs(SpontelData['y'] * 0.001)
SpontelData['Temperature'] = xdataraw
SpontelData['sigma_T'] = [0.1] * len(SpontelData['Temperature'])
SpontelData['weight'] = [1] * len(SpontelData['Temperature'])

y=np.array(SpontelData.y)
sigy=np.array(SpontelData.sigma_y)
Temp=np.array(SpontelData.Temperature)
sigT=np.array(SpontelData.sigma_T)
Eobs=np.array(SpontelData.Observed_field)
weight=np.array(SpontelData.weight)

#define some empty arrays to hold data
ndata=len(weight)
ymodel=np.array([0.0]*ndata)
sqroot=np.array([0.0]*ndata)
sqroot_A=np.array([0.0]*ndata)
sqroot_B=np.array([0.0]*ndata)

#convert more numbers to au
Temp_au = Temp/315774.64
IceMu_au =  IceMu*0.393456

EScur = Guess_E_S_Vm
EAcur = Guess_E_A_Vm
ESzetacur = EScur*Guess_zeta

for i in range(0,ndata):        
        ymodel[i]=Langevin((EScur-EAcur*y[i]+ESzetacur*1*y[i]*y[i])*IceMu*Ttoau*Debye/Etoau/Temp[i])
        
ymodel_E=Guess_E_A_Vm*ymodel
   
SpontelData['calc_y'] = ymodel
SpontelData['Calc_field'] = ymodel_E
SpontelData['DE_eV'] = DE_eV_lower
spont_file_name = os.path.join(folder_path, which_peak+'_'+ str(r_nm) + '_spont.csv')
SpontelData.to_csv(spont_file_name, index=False)

PlotSpontelData_paper(SpontelData['Temperature'], SpontelData['sigma_T'], SpontelData['Calc_field'], SpontelData['Observed_field'], SpontelData['calc_y'], SpontelData['y'], SpontelData['sigma_y'], ax5, ax6)

ax1.text(0.05, 0.95, 'a)', transform=ax1.transAxes, fontsize=10, verticalalignment='top')
ax2.text(0.05, 0.95, 'b)', transform=ax2.transAxes, fontsize=10, verticalalignment='top')
ax3.text(0.05, 0.95, 'c)', transform=ax3.transAxes, fontsize=10, verticalalignment='top')
ax4.text(0.05, 0.95, 'd)', transform=ax4.transAxes, fontsize=10, verticalalignment='top')
ax5.text(0.05, 0.95, 'e)', transform=ax5.transAxes, fontsize=10, verticalalignment='top')
ax6.text(0.05, 0.95, 'f)', transform=ax6.transAxes, fontsize=10, verticalalignment='top')

#fix x-axes details
ax1.xaxis.set_tick_params(labeltop=True)
ax2.xaxis.set_tick_params(labeltop=True)
ax1.set_xlabel('temperature (K)', fontsize=14, labelpad = 20, x = 1)
#ax2.set_xlabel('Temperature (K)', fontsize=14, labelpad = 20)
# Move x-axis label to the top
ax1.xaxis.label_position = 'top'
ax2.xaxis.label_position = 'top'
#ax6.set_xlabel('Temperature (K)', fontsize=14)
ax5.set_xlabel('temperature (K)', fontsize=14,x = 1)

#fix y-axes details
ax3.set_ylabel('electric Field ($x10^{6}$ Vm$^{-1}$)', fontsize=14)
ax4.set_ylabel(r'dipole orientation, m ($x10^{-5}$) ', fontsize=14)

# Set offset text color to white
ax1.get_yaxis().get_offset_text().set_color('white')
ax2.get_yaxis().get_offset_text().set_color('white')
ax3.get_yaxis().get_offset_text().set_color('white')
ax4.get_yaxis().get_offset_text().set_color('white')
ax5.get_yaxis().get_offset_text().set_color('white')
ax6.get_yaxis().get_offset_text().set_color('white')

#add a legend
ax1.legend(frameon = False)

# Save the combined plot
plt.savefig('Figure_4.png',dpi = 600, bbox_inches='tight')
plt.savefig('Figure_4.svg',dpi = 600, bbox_inches='tight')
plt.show()
# Out:
# All files in 'observed_data' have been deleted.
#
#
# radius used:  9.5 nm
# Calculated value of E_A is -6.514 x 10^10 V/m
# The fit parameters for the spontelectric model :
# $E_S =$$(1.9917\,\pm\,0.0012)\times 10^{6}$
# $E_A =$$(-6.5145\,\pm\,0.0018)\times 10^{10}$
# $\zeta =$$(2.6273\,\pm\,0.0021)\times 10^{8}$
# reduced $\chi^2 =$0.0
#
#
# radius used:  9.75 nm
# Calculated value of E_A is -6.514 x 10^10 V/m
# The fit parameters for the spontelectric model :
# $E_S =$$(1.8975\,\pm\,0.0011)\times 10^{6}$
# $E_A =$$(-6.5145\,\pm\,0.0018)\times 10^{10}$
# $\zeta =$$(2.8945\,\pm\,0.0023)\times 10^{8}$
# reduced $\chi^2 =$0.0
#
#
# radius used:  10.0 nm
# Calculated value of E_A is -6.514 x 10^10 V/m
# The fit parameters for the spontelectric model :
# $E_S =$$(1.8099\,\pm\,0.0011)\times 10^{6}$
# $E_A =$$(-6.5145\,\pm\,0.0018)\times 10^{10}$
# $\zeta =$$(3.1815\,\pm\,0.0026)\times 10^{8}$
# reduced $\chi^2 =$0.0
#
#
# ...

# %% [markdown]
# **Figure 4**<a class="anchor" id="figure_4"></a>: _Comparing the exciton model, Eqns. 1 – 3 (black circles), and the spontelectric model, Eqns. 4&5 (red triangles) for electric fields (left column), and dipole orientation (right column) arising in $I_h$. a&b) Using data for the higher energy spectral line, with the fitted values of $E_A$, $E_S$ and $\zeta$ given in the text and an exciton of size r = 9.75$\,$nm. c&d) Illustrating the sensitivity of results to values of exciton size between r = 9.5$\,$nm and 10.0$\,$nm. Beyond the range shaded in grey, consistency deteriorates establishing that the systematic error in the field is $\sim\pm\,$0.2$\,\times \,$10$^5$$\,$Vm$^{-1}$ and in $m$ is $\sim\pm\,$0.2$\,\times \,$10$^{-5}$. Solid red lines have been introduced to guide the eye. e&f); as in a&b but for the lower energy spectral line relating to cubic ice, using the same values of $E_A$, $E_S$ and $\zeta$ as in panels a&b, recollecting that cubic ice is subjected to the field generated by hexagonal ice and does not itself generate a spontelectric field. The lower quality of the data, associated with the 1% proportion of cubic ice and evaporation at 140$\,$K (see text), is reflected in the poorer consistency achieved between the exciton model and spontelectric model._

# %% [markdown]
# #### Table 1

# %%
### Table 1.
filename='water_spont_data' #these peak positins come from Gaussian fits to water data. 
df = pd.read_csv(filename+'.csv', header=(0))
data_files = 'observed_data/8_6_9.75_spont.csv'
spont_fit1_best = pd.read_csv(data_files, header = (0))
data_files = 'observed_data/7_9_9.75_spont.csv'
spont_fit2_best = pd.read_csv(data_files, header = (0))

# Create a new dataframe 'table_1'
table_1 = pd.DataFrame()

# Add columns from 'df' to 'table_1'
table_1['Temperature / K'] = df['Temperature_K']
table_1['Higher energy peak / eV'] = df['8_5eV_peak_eV'].round(3)
table_1['Lower energy peak / eV'] = df['8eV_peak_eV'].round(3)

# Add columns from 'spont_fit1_best' to 'table_1'
table_1['Higher energy peak, electric field - exciton model / V m-1'] = spont_fit1_best['Observed_field'].round(3).map('{:.3e}'.format)
table_1['Higher energy peak, electric field - spontelectric model / V m-1'] = spont_fit1_best['Calc_field'].round(3).map('{:.3e}'.format)

# Add columns from 'spont_fit2_best' to 'table_1'
table_1['Lower energy peak, electric field - exciton model / V m-1'] = spont_fit2_best['Observed_field'].round(3).map('{:.3e}'.format)
table_1['Lower energy peak, electric field - spontelectric model / V m-1'] = spont_fit2_best['Calc_field'].round(3).map('{:.3e}'.format)

print(table_1)
# Out:
#    Temperature / K  Higher energy peak / eV  Lower energy peak / eV  \
# 0            127.5                    8.642                   7.981
# 1            130.0                    8.636                   7.978
# 2            135.0                    8.625                   7.970
# 3            137.5                    8.617                   7.961
# 4            140.0                    8.601                   7.960
#
#   Higher energy peak, electric field - exciton model / V m-1  \
# 0                                          3.986e+06
# 1                                          3.968e+06
# 2                                          3.929e+06
# 3                                          3.898e+06
# 4                                          3.823e+06
#
#   Higher energy peak, electric field - spontelectric model / V m-1  \
# 0                                          3.984e+06
# 1                                          3.973e+06
# ...

# %% [markdown]
# **Table 1**<a class="anchor" id="table_1"></a>:  _Peak positions and electric field strengths, calculated on the basis both of the exciton model, using an exciton size of r = 9.75$\,$nm, and calculated on the basis of the spontelectric model, given a value of $E_A$ = -6.51449$\,\times \,$10$^{10}$$\,$Vm$^{-1}$ (see [Eqn. 4](#equation_3) et seq.). The numbers in parenthesis columns 2 and 3 indicate the uncertainty in the last digit for the peak position._

# %% [markdown]
# ### Discussion <a class="anchor" id="Discussion"></a>
#
# Onsager *et al.*,[8](#ref_8) in agreement with Kutzner,[37](#ref_37) ascribe the bulk polarization of water ice films wholly to dipole orientation, templated by the orientation that molecules achieve immediately after landing on the substrate. Subsequent work [6](#ref_6),[7](#ref_7),[9](#ref_9),[10](#ref_10) has shown that there is a significant contribution from pores in ice formed by deposition at 77$\,$K. Be that as it may, the data of Onsager *et al.* [8](#ref_8) based upon measurements of a thermally stimulated current measured at a copper substrate, give an electric field of 3.95$\,\times\,$10$^6\,$V$\,$m$^{-1}$ for ice deposited at liquid nitrogen temperature (77$\,$K). At this temperature there exists (i) the influence on the wavelength of absorption of very high local fields of the order of 10$^9\,$V$\,$m$^{-1}$ arising from pores in the ice and which affect the hydrogen bond energy[11](#ref_11),[12](#ref_12) and thus spectral transition energies and (ii) the presence of non-local spontelectric fields (termed in [8](#ref_8) as a ‘natural electret’) affecting the energy of excitons, themselves arising from the nanocrystalline nature of ASW. Note that similar fields to the latter have been observed in low temperature ammonia ices which are nanocrystalline.[38](#ref_38) The spontelectric fields which we derive for $I_{sd}$ ice at higher deposition temperatures relevant to crystalline ice, appear similar in value to the field derived at this one temperature of 77$\,$K from the data of Onsager *et al.* collected by quite different means and relevant to ASW.
#
# We note that the nature of the surface upon which spontelectric films are deposited has little or no bearing on the values of film polarization.[39](#ref_39) Thus, water ice deposited on substrates other than MgF$_2$, for example, interstellar grains composed of silicates, would yield the same spontelectric fields as reported here. Turning specifically to the interstellar medium, polarization in ice can have an important impact on the rate of formation of young stellar objects, by reducing the degree of ionization in protostellar clouds, hastening the formation of magnetically supercritical cores and thus enhancing the rate of star formation.[40](#ref_40) This may be relevant to the formation of massive galaxies in the early Universe observed recently using the James Webb Space Telescope.[41](#ref_41) It is known that water molecules in the ISM form in situ on the surface of cold dust grains, with temperatures of 10$\,$K, via reactions between mobile H atoms and O atoms, and that this eventually leads to the build-up of water ice. On a timescale of $\sim\,$105$\,$years, these reactions can form a typical coverage of 100 monolayers.[42](#ref_42) This first generation of ASW ice on grains in the ISM is created under very different conditions from those in our current experiment and is unlikely to be spontelectric. However, interstellar water ice is evaporated into the gas phase every 2$\,\pm\,$0.5$\,$Myr via interactions between dust grains and passing shocks.[40](#ref_40) This results in water concentrations $\sim\,$10$^{-4}$ of the molecular hydrogen number density, several orders of magnitude greater than any yield from gas phase water production. These stochastic high gas phase abundances are, for example, required to account for both the brightness and range of frequencies of water masers found in star-forming regions and around late type stars.[43](#ref_43) Thus a second, and possible subsequent, generation of water ice may indeed be spontelectric, formed as water ice layers recondense on cold dust grains following the passage of a shock.
#
# In addition, $I_{sd}$ ice is posited to be found in the Earth’s mesosphere and stratosphere, in Mars, Venus and elsewhere in the solar system.[29](#ref_29) Should such $I_{sd}$ ices be spontelectric, the consequent bound charge at the surface of ice particles in the solar systems may inhibit particle coagulation and therefore rocky planet formation, and ice particle nucleation rates in general.[44](#ref_44),[45](#ref_45)
#
#
# Although some crystalline water ice (*i.e.* at T$\,\geq\,$125$\,$K) has been described as porous,[46](#ref_46),[47](#ref_47),[48](#ref_48),[49](#ref_49) the structural properties of water ice are highly sensitive to its formation conditions and thermal history. Even within a single formation method such as vapour deposition, parameters including deposition temperature,[50](#ref_50) dosing method,[51](#ref_51),[52](#ref_52),[53](#ref_53) thermal history,[54](#ref_54) and film thickness [50](#ref_50),[54](#ref_54) can significantly affect porosity. These dependencies show that porosity cannot be generalised across vapour deposited ices without accounting for growth conditions and thermal history. Our deposition conditions and film thickness most closely match those of Kimmel *et al.*,[54](#ref_54) suggesting that our water ices grown above the transition temperature of 125$\,$K are more likely non-porous crystalline ices, see supporting information. In contrast, porous crystalline ices have typically been produced via fundamentally different formation routes, such as freezing of liquid water,[47](#ref_47) or for much greater film thicknesses  and different thermal histories.[48](#ref_48),[50](#ref_50),[55](#ref_55).

# %% [markdown]
# ### Conclusion<a class="anchor" id="Conclusion"></a>
#
# With this report, we have described polarization in crystalline ice $I_h$ as a bulk property that arises following the collective alignment of dipoles throughout the water film. Future work will aim at synthesising and characterising polarization in different ice polymorphs by controlling the temperature and pressure during film growth.  The interest regarding the presence of spontaneous fields in crystalline ice is manifold. Polarization will affect ice particle nucleation rates,[44](#ref_44) and can impact on the rate of formation of young stellar objects in the ISM. Electric fields in thin films might be also harnessed to separate charge carriers upon photoionization,[56](#ref_56), migrate solvated ions towards an interface or polarise bonds in solvated target molecules to affect the rate of chemical reactions.[57](#ref_57)

# %% [markdown]
# ### Acknowledgements <a class="anchor" id="Acknowledgements"></a>
# We acknowledge the Centre for Storage Ring Facilities at Aarhus (ISA) for granting access to the VUV beamline on the ASTRID2 storage ring. We also thank the staff at ISA for their technical assistance in performing our experiments, with special thanks to Nykola Jones and Søren Hoffmann. This work was supported by the Danish National Research Foundation through the Center of Excellence “InterCat” (Grant Agreement No. DNRF150), VILLUM FONDEN, through grant No. VIL70175.).

# %% [markdown]
# ### Author Contributions <a class="anchor" id="Author_Contributions"></a>
#
# RJ, and DF carried out VUV experiments; LB carried out IR experiments. AC DF and FP developed the theory and carried out numerical simulations; all authors contributed extensively to the interpretation of the data and the production of the manuscript

# %% [markdown]
# ### Data Availability <a class="anchor" id="Data_Availability"></a>
# All data and analysis codes will be hosted on zenodo following publication

# %% [markdown]
# ### References <a class="anchor" id="references"></a>
#
# 1	S. G. Boxer and T. Head-Gordon, Chem. Rev., 2025, 125, 6871–6873.
#
# 2	J. D. Bernal and R. H. Fowler, J. Chem. Phys., 1933, 1, 515–548.
#
# 3	P. Geiger, C. Dellago, M. Macher, C. Franchini, G. Kresse, J. Bernard, J. N. Stern and T. Loerting, J. Phys. Chem. C, 2014, 118, 10989–10997.
#
# 4	A. Kouchi, T. Yamazaki, H. Katsuno, H. Nada, T. Hama and Y. Kimura, Chemical Physics, 2023, 572, 111966.
#
# 5	I. A. Ryzhkin, Nature Phys, 2016, 12, 996–997.
#
# 6	C. Bu, J. Shi, U. Raut, E. H. Mitchell and R. A. Baragiola, J. Chem. Phys., 2015, 142, 134702.
#
# 7	R. Sagi, M. Akerman, S. Ramakrishnan and M. Asscher, J. Chem. Phys., 2020, 153, 144702.
#
# 8	L. Onsager, D. L. Staebler and S. Mascarenhas, J. Chem. Phys., 1978, 68, 3823–3828.
#
# 9	M. J. Iedema, M. J. Dresser, D. L. Doering, J. B. Rowland, W. P. Hess, A. A. Tsekouras and J. P. Cowin, J. Phys. Chem. B, 1998, 102, 9203–9214.
#
# 10	T. Tomaru, H. Hidaka, A. Kouchi and N. Watanabe, Physical Chemistry Chemical Physics, 2024, 26, 15232–15239.
#
# 11	I. Mata, E. Molins, I. Alkorta and E. Espinosa, The Journal of Chemical Physics, 2009, 130, 044104.
#
# 12	S. D. Fried and S. G. Boxer, Acc. Chem. Res., 2015, 48, 998–1006.
#
# 13	S. Rasoul Hashemi, M. R. S. McCoustra, H. J. Fraser and G. Nyman, Physical Chemistry Chemical Physics, 2022, 24, 12922–12925.
#
# 14	H. Fukazawa, S. Ikeda and S. Mae, Chemical Physics Letters, 1998, 282, 215–218.
#
# 15	P. Parkkinen, S. Riikonen and L. Halonen, J. Phys. Chem. C, 2014, 118, 26264–26275.
#
# 16	T. Sugimoto, N. Aiga, Y. Otsuki, K. Watanabe and Y. Matsumoto, Nature Phys, 2016, 12, 1063–1068.
#
# 17	N. Aiga, T. Sugimoto, Y. Otsuki, K. Watanabe and Y. Matsumoto, Phys. Rev. B, 2018, 97, 075410.
#
# 18	A. Cassidy, M. R. S. McCoustra and D. Field, Acc. Chem. Res., 2023, 56, 1909–1919.
#
# 19	M. S. Westley, G. A. Baratta and R. A. Baragiola, J. Chem. Phys., 1998, 108, 3321–3326.
#
# 20	A. Cassidy, R. L. James, A. Dawes, J. Lasne and D. Field, Phys. Chem. Chem. Phys., 2019, 21, 1190–1197.
#
# 21	Y. Ozaki, Y. Morisawa, A. Ikehata and N. Higashi, Appl Spectrosc, 2012, 66, 1–25.
#
# 22	R. Onaka and T. Takahashi, J. Phys. Soc. Jpn., 1968, 24, 548–550.
#
# 23	K. Kobayashi, J. Phys. Chem., 1983, 87, 4317–4321.
#
# 24	T. Shibaguchi, H. Onuki and R. Onaka, J. Phys. Soc. Jpn., 1977, 42, 152–158.
#
# 25	R. Mota, R. Parafita, A. Giuliani, M.-J. Hubin-Franskin, J. M. C. Lourenço, G. Garcia, S. V. Hoffmann, N. J. Mason, P. A. Ribeiro, M. Raposo and P. Limão-Vieira, Chemical Physics Letters, 2005, 416, 152–159.
#
# 26	B. D. Bursulaya, J. Jeon, C.-N. Yang and H. J. Kim, J. Phys. Chem. A, 2000, 104, 45–52.
#
# 27	T. L. Malkin, B. J. Murray, C. G. Salzmann, V. Molinero, S. J. Pickering and T. F. Whale, Phys. Chem. Chem. Phys., 2014, 17, 60–76.
#
# 28	J. E. Shilling, M. A. Tolbert, O. B. Toon, E. J. Jensen, B. J. Murray and A. K. Bertram, Geophysical Research Letters, DOI:10.1029/2006GL026671.
#
# 29	C. G. Salzmann, B. J. Murray, M. G. Fox-Powell, R. E. Hamp, A. Rosu-Finsen and H. Fraser, Icarus, 2024, 410, 115897.
#
# 30	L. Lupi, A. Hudait, B. Peters, M. Grünwald, R. Gotchy Mullen, A. H. Nguyen and V. Molinero, Nature, 2017, 551, 218–222.
#
# 31	B. S. Berland, D. E. Brown, M. A. Tolbert and S. M. George, Geophysical Research Letters, 1995, 22, 3493–3496.
#
# 32	D. Field, O. Plekan, A. Cassidy, R. Balog, N. C. Jones and J. Dunger, International Reviews in Physical Chemistry, 2013, 32, 345–392.
#
# 33	Y. H. Zhao, M. H. Abraham and A. M. Zissimos, J Org Chem, 2003, 68, 7368–7373.
#
# 34	Kittel, Introduction to Solid State Physics, 7th ed, Wiley India Pvt. Limited, 2007.
#
# 35	A. Cassidy, F. P. Pijpers and D. Field, The Journal of Chemical Physics, 2023, 158, 144501.
#
# 36	The authors have made an executable version of this paper with data and data analysis methods openly available. If the paper is accepted, this resource will be archived at the Zenodo database and assigned a DOI.
#
# 37	K. Kutzner, Thin Solid Films, 1972, 14, 49–61.
#
# 38	A. Cassidy, R. L. James, A. Dawes and D. Field, ChemistryOpen, 2020, 9, 983–990.
#
# 39	O. Plekan, A. Rosu-Finsen, A. M. Cassidy, J. Lasne, M. R. S. McCoustra and D. Field, Eur. Phys. J. D, 2017, 71, 162.
#
# 40	A. Rosu-Finsen, J. Lasne, A. Cassidy, M. R. S. McCoustra and D. Field, ApJ, 2016, 832, 1.
#
# 41	I. Labbé, P. van Dokkum, E. Nelson, R. Bezanson, K. A. Suess, J. Leja, G. Brammer, K. Whitaker, E. Mathews, M. Stefanon and B. Wang, Nature, 2023, 616, 266–269.
#
# 42	H. M. Cuppen, S. Ioppolo, C. Romanzin and H. Linnartz, Phys. Chem. Chem. Phys., 2010, 12, 12077–12088.
#
# 43	J. A. Yates, D. Field and M. D. Gray, Mon Not R Astron Soc, 1997, 285, 303–316.
#
# 44	D. A. Knopf and P. A. Alpert, Nat Rev Phys, 2023, 5, 203–217.
#
# 45	A. V. Ivlev, M. Padovani, D. Galli and P. Caselli, ApJ, 2015, 812, 135.
#
# 46	C. R. Hill, C. Mitterdorfer, T. G. A. Youngs, D. T. Bowron, H. J. Fraser and T. Loerting, Phys. Rev. Lett., 2016, 116, 215501.
#
# 47	T. Loerting, M. Bauer, I. Kohl, K. Watschinger, K. Winkel and E. Mayer, J. Phys. Chem. B, 2011, 115, 14167–14175.
#
# 48	C. M. Tonauer, E.-M. Köck, R. Henn, J. N. Stern, L. Del Rosso, M. Celli, C. Kappacher, S. Leiter, C. G. Kirchler, C. W. Huck and T. Loerting, ApJ, 2024, 970, 82.
#
# 49	H. Wu, W. Kong, P. Bian and H. Liu, AS, 2024, 7, 11–28.
#
# 50	Z. Amato, T. F. Headen, S. Gärtner, P. Ghesquière, T. G. A. Youngs, D. T. Bowron, L. Cavalcanti, S. E. Rogers, N. Pascual, O. Auriacombe, E. Daly, R. E. Hamp, C. R. Hill, R. K. Tp and H. J. Fraser, Phys. Chem. Chem. Phys., 2025, 27, 6616–6627.
#
# 51	D. E. Brown, S. M. George, C. Huang, E. K. L. Wong, K. B. Rider, R. S. Smith and B. D. Kay, J. Phys. Chem., 1996, 100, 4988–4995.
#
# 52	M. S. Westley, G. A. Baratta and R. A. Baragiola, J. Chem. Phys., 1998, 108, 3321–3326.
#
# 53	K. P. Stevenson, G. A. Kimmel, Z. Dohnálek, R. S. Smith and B. D. Kay, Science, 1999, 283, 1505–1507.
#
# 54	G. A. Kimmel, K. P. Stevenson, Z. Dohnálek, R. S. Smith and B. D. Kay, J. Chem. Phys., 2001, 114, 5284–5294.
#
# 55	C. R. Hill, C. Mitterdorfer, T. G. A. Youngs, D. T. Bowron, H. J. Fraser and T. Loerting, Phys. Rev. Lett., 2016, 116, 215501.
#
# 56	F. Chen, H. Huang, L. Guo, Y. Zhang and T. Ma, Angewandte Chemie International Edition, 2019, 58, 10061–10073.
#
# 57	S. Shaik, D. Danovich, J. Joy, Z. Wang and T. Stuyver, J. Am. Chem. Soc., 2020, 142, 12551–12562.
#
# ter Ice in the UV–vis. ApJ 875, 131 (2019).

# %% [markdown]
# # Supplementary Materials <a class="anchor" id="Acknowledgements"></a>

# %% [markdown]
# ## Spontaneously polarised crystalline water ice
#
# _Authors: Rachel James (1), Frank Pijpers (2), Lars Borchert (3), David Field (3), Andrew Cassidy* (3)_
#
# (1) Department of Earth and Environmental Sciences, The University of Manchester, Manchester, UK<br>
# (2) Korteweg - de Vries Institute for Mathematics, University of Amsterdam, Amsterdam, Netherlands<br>
# (3) Center for Interstellar Catalysis, Department of Physics and Astronomy, Aarhus University, Aarhus, Denmark<br>
#
# *corresponding author amc@phys.au.dk<br>

# %% [markdown]
# ### Abstract <a class="anchor" id="abstract_sup"></a>
#
# We describe a novel aspect of the structure of the hexagonal phase of crystalline water ice, using vacuum-ultraviolet absorption spectroscopy as a diagnostic tool. The key result is that hexagonal ice ($I_h$), prepared from condensation of pure water vapour, displays net molecular orientation. This reflects order in the disposition of the protons in ice $I_h$ and our results require revision of the near century old conventional structure in which water molecular dipoles point in random directions in hexagonal ice. Orientation gives rise to spontaneous polarization and internal fields of $~4 \times 10^6\,$ Vm$^{-1}$ in films of ice $I_h$ tens of nanometres thick, condensed on an insulating MgF$_2$ substrate. Data are in the form of Stark shifts in absorption spectra, with no free charges or external electric fields introduced in the experiment.
#
# This document contains supplementary material that aids the reader in understanding the content of the published letter.
#
# Contents:
#
# 1.	[VUV absorption spectra for water ice films grown at temperatures between 20 K and 140 K](#sup_1)
#
# 2.	[Details on peak fitting routine](#sup_2)
#
# 3.	[Figure showing i) peak position as a function of film growth temperature and ii) time resolved data illustrating a phase transition from amorphous solid water to crystalline water ice.](#sup_3)
#
# 4.	[Relative density changes between films prepared at different temperatures.](#sup_4)
#
# 5.	[An introduction to the executable version of this manuscript.](#sup_5)
#
# 6.	[References.](#sup_6)

# %% [markdown]
# ### Sup Mat.1 - VUV absorption spectra for water ice films grown at temperatures between 20 K and 140 K<a class="anchor" id="sup_1"></a>

# %%
### Plot Figure 1 - for Sup Mat
#--------------------------------------------------------

###
### 1. We only want to compare films of approximately the same thickness and some are very close. we need to remove ambiguity
###

temperatures = np.array(obs_all_data.temp)
depositions = np.array(obs_all_data.dep)
peak1_positions = np.array(obs_all_data.peak1)
peak2_positions = np.array(obs_all_data.peak2)
peak1_err = np.array(obs_all_data.peak1_err)
peak2_err = np.array(obs_all_data.peak2_err)

#get list of required temps and deps
temp_dep_pos = list(zip(temperatures, depositions, peak1_positions, peak2_positions,peak1_err ,peak2_err ))

# Use a loop to remove the second thickest film in places where the thcikness is very close
filtered_temp_dep_pos  =  []
for i in range(1, len(temp_dep_pos)):
#    # If the current element is not the same as the previous element
    if temp_dep_pos[i][0] != temp_dep_pos[i-1][0]:
#        # Add the previous element to the filtered list
        filtered_temp_dep_pos.append(temp_dep_pos[i-1])
## Add the last element
filtered_temp_dep_pos.append(temp_dep_pos[-1])

#send this data to a dataframe
filtered_temp_dep_pos_df = pd.DataFrame(filtered_temp_dep_pos, columns=['Temperature_K', 'depositon#', '8_5eV_peak_eV', '8eV_peak_eV', '8_5eV_err', '8eV_err'])
df_selected = filtered_temp_dep_pos_df[['Temperature_K', '8_5eV_peak_eV', '8eV_peak_eV','8_5eV_err', '8eV_err']]
# Saving the selected columns to a CSV file
df_selected.to_csv('water_best_positions.csv', index=False)

# Save the spont rows, i.e., the data that corresponds to a crystalline films, to a seperate text file 
df_spont = df_selected[df_selected['Temperature_K'] > 126]
df_spont.to_csv('water_spont_data.csv', index=False)

###
### 2. And finally, plot figure 1
###

peak1_values = filtered_temp_dep_pos_df['8_5eV_peak_eV']
peak2_values = filtered_temp_dep_pos_df['8eV_peak_eV']
filtered_temp = filtered_temp_dep_pos_df['Temperature_K']

#Get the csv data that stores xy data for each required temp and dep
best_spectra = []

#now extract the bkgd subtracted datacurves for filtered data sets
for fil_temp_dep_pos in filtered_temp_dep_pos:
    #   adjust for file naming - i.e. add  0.5 K to 127.5 and 137.5 K
    temperature_str = str(fil_temp_dep_pos[0])       
    temperature_str = temperature_str[:-2]
    if len(temperature_str) == 2:
    # Add a zero to the beginning
        temperature_str = '0' + temperature_str
    if temperature_str[-1] == "7":
    # add "-5"
        temperature_str += "-5"
    #add text 
    temperature_str +="K_dep"+str(fil_temp_dep_pos[1])
    temperature_str  = temperature_str[:-1]+"csv"
    best_spectra.append(temperature_str)

#print(best_spectra)

# Define the colormap
cmap = plt.get_cmap('coolwarm')

# Define the offset for the waterfall plot
offset = 0

# define the figure
fig, ax1 = plt.subplots(figsize=(5,7))

#Add the Gaussian fit for the first spectrum to the plot
first_spectrum = pd.read_csv(os.path.join(export_path, best_spectra[0])) #11th index is 125 K, 0th index would be 20 K
first_spectrum['photon_energy'] = WLtoE(first_spectrum.iloc[:, 0])
check_index = find_closest_match(first_spectrum, peak1_values,0, 0)[0]
offset = 0.05
first_spectrum['Normalized_Gauss_3'] = first_spectrum['Gauss_3'] - first_spectrum.iloc[find_closest_match(first_spectrum, peak1_values,0, 0)[0], 2]-offset
plt.plot(first_spectrum['photon_energy'],first_spectrum['Normalized_Gauss_3'], color = 'k', linestyle = '--')
#ax1.fill_between(first_spectrum['photon_energy'], first_spectrum['Normalized_Gauss_3'].min(), first_spectrum['Normalized_Gauss_3'], facecolor="0.8", alpha=0.5)

first_spectrum['Normalized_Gauss_1'] = first_spectrum['Gauss_1'] - first_spectrum.iloc[find_closest_match(first_spectrum, peak1_values,0, 0)[0], 2]-offset
plt.plot(first_spectrum['photon_energy'],first_spectrum['Normalized_Gauss_1'], color = 'k', linestyle = '-.')
#ax1.fill_between(first_spectrum['photon_energy'], first_spectrum['Normalized_Gauss_1'].min(), first_spectrum['Normalized_Gauss_1'], facecolor='0.6', alpha=0.5)

first_spectrum['Normalized_Gauss_2'] = first_spectrum['Gauss_2'] - first_spectrum.iloc[find_closest_match(first_spectrum, peak1_values,0, 0)[0], 2]-offset
plt.plot(first_spectrum['photon_energy'],first_spectrum['Normalized_Gauss_2'], color = 'k', linestyle = ':')
#ax1.fill_between(first_spectrum['photon_energy'], first_spectrum['Normalized_Gauss_2'].min(), first_spectrum['Normalized_Gauss_2'], facecolor="0.4", alpha=0.5)

first_spectrum['Normalized_Gauss_4'] = first_spectrum['Gauss_4'] - first_spectrum.iloc[find_closest_match(first_spectrum, peak1_values,0, 0)[0], 2]-offset
plt.plot(first_spectrum['photon_energy'],first_spectrum['Normalized_Gauss_4'], color = 'k')
#ax1.fill_between(first_spectrum['photon_energy'], first_spectrum['Normalized_Gauss_4'].min(), first_spectrum['Normalized_Gauss_4'], facecolor="0.2", alpha=0.5)

first_spectrum['Normalized_Gauss_fit'] = first_spectrum['Gauss_fit'] - first_spectrum.iloc[find_closest_match(first_spectrum, peak1_values,0, 0)[0], 2]
ax1.plot(first_spectrum['photon_energy'], first_spectrum['Normalized_Gauss_fit'], color='red', linestyle='--')#,  alpha=0.3)

offset = 0
#get each curve ready for the plot
for i, file in enumerate (sorted(best_spectra)): 
    # Construct the full file path
    file_path = os.path.join(export_path, file)    
    # Read the csv file into a dataframe
    df = pd.read_csv(file_path)    
    #Convert the nm values in eV
    df['photon_energy'] = WLtoE(df.iloc[:, 0])  
    
    # Plot the first two columns of the dataframe and add a point for the peak maximum    
    peak_energy = find_closest_match(df, peak1_values, i, offset) #find absorbance at top of peak 1
    ax1.plot(peak1_values[i], offset, 'ko') 
    ax1.plot(peak2_values[i], find_closest_match(df, peak2_values,i, offset)[2]+offset-(find_closest_match(df, peak1_values,i, offset)[2]), 'r^')     
    absorbance = df['absorbance']  + offset  #add the offset to the absorbance column for plotting
    df['Normalized Absorbance'] = absorbance - df.iloc[find_closest_match(df, peak1_values,i, offset)[0], 2]
    legend_label =str(filtered_temp[i])
    legend_label=legend_label[:-2]+' K'
    ax1.plot(df['photon_energy'], df['Normalized Absorbance'], label=legend_label, color=cmap((i) / len(best_spectra)))
    ax1.text(10.1, df['Normalized Absorbance'].max()+0.0,legend_label,color=cmap((i) / len(best_spectra)))
    # Increase the offset
    offset += 0.28

# set figure details
ax1.set_xlabel('photon energy (eV)', fontsize = 14)
ax1.set_xlim(7.0,10.5)
ax1.tick_params(axis='x', direction='inout', labelsize = 14, length=5, top = True)
ax1.minorticks_on()
ax1.tick_params(axis='x', which='minor', direction='out', length=2, top=True, bottom=True)

ax1.tick_params(axis='y', direction='inout', length=5, labelsize = 16, labelleft = False)
ax1.set_ylabel('absorbance', fontsize = 14)

#adjust the y-ticks so that 0 is at 0
yticks = np.array([0,1,2,3,4,5,6])
ax1.set_yticks(first_spectrum['Normalized_Gauss_fit'].min()+yticks, yticks)
ax1.set_ylim(first_spectrum['Normalized_Gauss_4'].min(),4.8)
#ax1.tick_params(axis='y', which='minor', labelsize = 22, direction='out', length=0)

# Create a twin y-axis
ax2 = ax1.twinx()
# Label the secondary y and x -axes
ax2.set_yticks(first_spectrum['Normalized_Gauss_fit'].min()+yticks, yticks)
ax2.tick_params(axis='y', direction='inout', labelsize = 18, length=5,labelright=False)
ax2.set_ylim(first_spectrum['Normalized_Gauss_4'].min(),5)

#plt.legend()

# Save the figure as a PNG file
fig.savefig('Figure_1_sup_mat.png',dpi = 600, bbox_inches='tight' , format='png')
fig.savefig('Figure_1_sup_mat.svg',dpi = 600, bbox_inches='tight' , format='svg')

plt.show()

# %% [markdown]
# **Figure 1 - Sup Mat** <a class="anchor" id="sup_figure_1"></a>: _Absorption spectra of $\sim$8$\,$nm ($\sim$30$\,$ML) water ice films grown between T = 20$\,$K and 140$\,$K. Spectra are displaced on the vertical axis and all possess a maximum absorbance of $\sim$0.6. Transitions centred around the high energy (black circles) and low energy (red triangles) are attributed to the (1b$_1$)(4$_{a1}$) A $^1$B$_1$ $\leftarrow$ (1b$_1$)$^2$ X $^1$A$_1$ transition in $I_h$ and $I_c$ respectively. The dashed lines show the Gaussian fits to the spectrum at 20$\,$K, with the resulting fit to the data shown in red beneath this spectrum as a typical example. All data and fits are available in the executable version of the paper (see [section 5](#sup_5))._
#
# Note that films of pure water ice were condensed, from a partial pressure of ~10$^{-7}$$\,$mbar, onto a cold MgF$_2$ substrate maintained at a fixed temperature and acting as a VUV window, held inside a chamber with a base pressure <2 x 10$^{-8}$$\,$mbar. Data were taken on the UV beamline on the ASTRID2 facility at Aarhus University. Film thicknesses were quantified using a laser interferometer technique. A new film is laid down at each temperature and films are not heated or cooled before spectra are taken.

# %% [markdown]
# ### Sup Mat.2 - Details on peak fitting routine <a class="anchor" id="sup_2"></a>
#
# At a given film growth temperature, several spectra were collected following incremental doses to increase water ice film thickness. Typically, this led to four or five spectra at each growth temperature. All spectra were fit simultaneously using a linear combination of four Gaussians. Three of these Gaussians represent features resulting from the water film and are shown in [Sup Mat Fig. 1](#sup_1) above. The fourth Gaussian was included to account for a small peak at 6.5$\,$eV. This fourth peak, labelled “fourth peak” in the fitting routine, was observed with identical parameters in each spectrum, *i.e.*, the peak did not grow with increasing water doses and did not shift in position as a function of film thickness nor changes to film growth temperature. This peak had an absorbance below 0.05 in all spectra.
#
# The equation used to describe a Gaussian peak amplitude, *i.e.*, absorbance (Abs), at a given photon energy, $x$ (eV), was
#
# [Sup Mat - Eqn. 1]<a class="anchor" id="sup_equation_1"></a>
# \begin{align}
# \mathrm{(Sup Mat 1)} \quad Abs = Ae^{\frac {x-x0^2}{2sig^2}}
# \end{align}
#
# where $A$ is the peak amplitude, $x0$ is the peak position and $sig$ is the peak width (*i.e.*, FWHM). This gives four peaks each with 3 fitting parameters, giving 12 variables for each spectrum. These variables were constrained with bounding values to allow the fitting routine to converge. These bounds are described in [Sup Mat Table 1](#sup_table_1). The Gaussian labelled *“BkGd peak”* in [Sup Mat Table 1](#sup_table_1) represents the rising continuum towards the first ionisation energy for water ice and at least in gas phase spectra continues to grow in absorbance at energies that are outside the range of our experiment. The Gaussians labelled *“BkGd peak”* and *“fourth peak”* were tightly constrained in position but the peaks that are the focus of this investigation, *“Higher Energy Peak”* and *“Lower Energy Peak”* were fit with parameters that lie well within the bounds, *i.e.*, the position and width of these peaks were not constrained by the choice of bounds. This is more easily visualised by exploring the executable paper described in [section 4](#sup_4).

# %% [markdown]
# | Peak               | Amplitude (lower) | Amplitude (upper) | Position (lower) | Position (upper) | Width (lower) | Width (upper) |
# |--------------------|--------------------|--------------------|-------------------|-------------------|---------------|---------------|
# | Higher Energy Peak | 0.01              | 1.2               | 8.0              | 8.9              | 0.37          | 0.4           |
# | Lower Energy Peak  | 0.01              | 0.4               | 7.2              | 8.5              | 0.1           | 0.3           |
# | BkGd Peak          | 0                 | 1.3               | 10.8             | 10.9             | 1.2           | 1.23          |
# | Fourth Peak        | 0                 | 0.05              | 6.45             | 6.55             | 0             | 0.25          |

# %% [markdown]
# **Sup Mat Table 1** <a class="anchor" id="sup_table_1"></a>:  _The bounds used to constrain four Gaussians peaks that were fit to all water absorption spectra are described. These bounds constrain the amplitude, position and width of each of the four Gaussians within an upper and lower limit. The four Gaussians describe the “higher energy peak” ascribed to $I_h$; the “lower energy peak” ascribed to $I_c$; the “BkGd peak” used to describe the rising continuum towards the first ionisation energy; and “fourth peak” at lower energies than the water spectrum._

# %% [markdown]
# ### Sup Mat.3 - A phase transition between amorphous solid water and crystalline water <a class="anchor" id="sup_3"></a>

# %%
###
### Figure 2 - for supplementary materials

### Fit exponentials to the time resolved data
### --------------------

# Find the data
x_data = time_p['time']
y_data1 = time_p['peak1']
y_data2 = time_p['peak2']

# Initial guess for the parameters [a, b, c]
initial_guess = [2, 0.001, 1]

# Fit the exponential decay function to the data
params1, covariance1 = curve_fit(exponential_decay, x_data, y_data1, p0=initial_guess)
params2, covariance2 = curve_fit(exponential_decay, x_data, y_data2, p0=initial_guess)

# Extract the fitted parameters
a_fit1, b_fit1, c_fit1 = params1
a_fit2, b_fit2, c_fit2 = params2

# Generate fitted y-values using the fitted parameters
y_fit1 = exponential_decay(x_data, a_fit1, b_fit1, c_fit1)
y_fit2 = exponential_decay(x_data, a_fit2, b_fit2, c_fit2)

# Extract standard errors of the parameters from the covariance matrix
perr1 = np.sqrt(np.diag(covariance1))
perr2 = np.sqrt(np.diag(covariance2))

# Calculate the error on the time constant
tau1 = 1 / b_fit1
tau2 = 1 / b_fit2

tau1_err = perr1[1] / (b_fit1 ** 2)
tau2_err = perr2[1] / (b_fit2 ** 2)

# Print the results
#print(f"Fitted parameters - peak 1:\na = {a_fit1}\nb = {b_fit1}\nc = {c_fit1}")
print(f"Time constant for decay of high energy peak = {round(tau1, 2)} ± {round(tau1_err, 2)} s")

#print(f"Fitted parameters - peak 2:\na = {a_fit2}\nb = {b_fit2}\nc = {c_fit2}")
print(f"Time constant for decay of low energy peak = {round(tau2, 2)} ± {round(tau2_err, 2)} s")

### Create a figure with a custom grid layout
### ------------------

fig = plt.figure(figsize=(8, 4))
gs = GridSpec(2, 2, height_ratios=[1, 1], width_ratios=[2, 1])

# Panel 1: Temperature-dependent data (left panel)

ax1 = fig.add_subplot(gs[:, 0])
ax1.errorbar(filtered_temp_dep_pos_df['Temperature_K'], filtered_temp_dep_pos_df['8_5eV_peak_eV'], yerr=filtered_temp_dep_pos_df['8_5eV_err'], fmt='o', color='black', label='8.5 eV')
ax1.set_xlabel('temperature (K)', fontsize=16)
ax1.set_ylabel('peak position (eV)', fontsize=16)
ax1.set_title('a)', loc='left', fontsize=16, x = -0.1)
ax1.yaxis.set_tick_params(right=True, labelright=False)
ax1.tick_params(axis='y', which='both', length=5, labelsize=14, direction='inout')
ax1.xaxis.set_ticks_position('both')
ax1.tick_params(axis='x', which='both', length=5, labelsize=14, direction='inout')
ax1.xaxis.set_major_locator(MultipleLocator(15))

# Panel 2: Time-decay_1 right top
#ax3 = fig.add_subplot(gs[1, 0])
ax3 = fig.add_subplot(gs[0, 1])
ax3.errorbar(x_data, y_data1, fmt='o', color='black', label='8.6 eV')
ax3.plot(x_data, y_fit1, alpha = 0.1)
#ax3.set_xlabel('time (s)',  fontsize=16)
#ax3.set_ylabel('peak position (eV)',  fontsize=14)
ax3.set_title('b)', loc='left', fontsize=16,x = -0.25, y = 0.95)
ax3.yaxis.set_tick_params(right=True, labelright=False)
ax3.tick_params(axis='y', which='both', length=5, labelsize=14, direction='inout')
ax3.xaxis.set_ticks_position('both')
ax3.tick_params(axis='x', which='both', length=5, labelsize=14, direction='inout')

# Panel 3: Time-decay_2 right bottom
ax5 = fig.add_subplot(gs[1, 1])
ax5.errorbar(x_data, y_data2, fmt='^', color='red', label='8 eV')
ax5.plot(x_data, y_fit2,'r', alpha = 0.1)
ax5.set_xlabel('time (s)', fontsize=16)
#ax5.set_ylabel('peak position / eV', fontsize=14)
ax5.set_title('c)', loc='left', fontsize=16,x = -0.25, y =0.95)
ax5.yaxis.set_tick_params(right=True, labelright=False)
ax5.tick_params(axis='y', which='both', length=5, labelsize=14, direction='inout')
ax5.xaxis.set_ticks_position('both')
ax5.tick_params(axis='x', which='both', length=5, labelsize=14, direction='inout')

# Adjust layout to add space between the panels
plt.tight_layout()
plt.subplots_adjust(hspace=0.4)  # Increase the space between the panels

# Save the figure as a PNG file
#fig.tight_layout()
fig.savefig('Figure_2_sup_mat.png',dpi = 600, bbox_inches='tight' ,format='png')
fig.savefig('Figure_2_sup_mat.svg',dpi = 600, bbox_inches='tight', format='svg')

# Show the plot
plt.show()
# Out:
# y_data1 -
#  0    8.608375
# 1    8.602653
# 2    8.597464
# 3    8.595258
# 4    8.592401
# 5    8.591643
# 6    8.590754
# 7    8.591310
# 8    8.590451
# Name: peak1, dtype: float64
# y_data2 -
#  0    7.953511
# 1    7.946656
# 2    7.943126
# 3    7.939780
# 4    7.937987
# 5    7.937682
# 6    7.936013
# 7    7.936248
# 8    7.936107
# Name: peak2, dtype: float64
# y_fit1 -
#  0    8.608473
# 1    8.602557
# 2    8.597334
# 3    8.594958
# 4    8.592873
# 5    8.591954
# 6    8.591051
# 7    8.590700
# 8    8.590409
# Name: time, dtype: float64
# y_fit2 -
#  0    7.953269
# 1    7.947378
# 2    7.942303
# 3    7.940053
# 4    7.938128
# 5    7.937300
# 6    7.936507
# 7    7.936208
# 8    7.935965
# Name: time, dtype: float64
# Time constant for decay of high energy peak = 1622.92 ± 100.18 s
# Time constant for decay of low energy peak = 1538.79 ± 135.53 s

# %% [markdown]
# **Figure 2 - Sup Mat** <a class="anchor" id="sup_figure_2"></a>: _a). Peak positions for the higher energy peak, marked with black dots in [Sup Mat Fig. 1](#sup_figure_1). Data indicate a phase change between 125$\,$K and 127.5$\,$K. Peak positions for the high energy (black dots - b) and low energy (red triangles - c) showing how peaks evolve with time at 125$\,$K. Exponential fits to the time evolution are shown. Errors, marked as vertical lines in (a), are 1$\,$SD on the Gaussian fit and amount to systematic errors of up to 3.$\,$meV and $\,$meV for the higher and lower energy peaks respectively._

# %% [markdown]
# Material is ASW for T$\leq$125$\,$K and crystalline for T$\geq$127.5$\,$K. At 125$\,$K, films become labile as they approach the phase transition, relaxing over a period of thousands of seconds. This temporal variation is illustrated in [Sup Mat Fig. 2b and c](#sup_figure_2) and within fitting errors has the same form for both spectral peaks, displaying time constants of 1622$\pm$100$\,$seconds for the higher energy peak and 1539$\pm$136$\,$seconds for the lower energy peak.
#
# Kelvin probe measurements, [1](#sup_ref_1),[2](#sup_ref_2),[3](#sup_ref_3) have reported weak fields permeating amorphous solid water (ASW) condensed on substrates below 125$\,$K. Our results, presented in [Sup Mat Fig 2a](#sup_figure_2), reproduce the form of the temperature dependence of these Kelvin Probe measurements. The reports of electric fields permeating amorphous solid water attribute the residual polarization to unbalanced dipoles in pores,[4](#sup_ref_4),[5](sup_ref_5) and this effect can be recreated using molecular dynamics simulations.[6](#sup_ref_6)
#
# A qualitative explanation for the variation of absorption wavelengths for data from ASW, between 20$\,$K and 125$\,$K in [Sup Mat Fig.2a](#sup_figure_2), rests upon theoretical estimates of the effect of an applied electric field on the energy of hydrogen bonds,[4](#sup_ref_4),[5](sup_ref_5) whose results may be summarized as follows: (i) local electric fields must be of the order of several x 10$^9$$\,$Vm$^{-1}$ to have an observable effect on hydrogen bond energy; (ii) such an electric field reduces the energy of hydrogen bonds when pointing in the same direction as the dipole moment of the system, as here, up to $\sim$100$\,$K; (iii) a switch in direction of the local electric field, implied by a switch in direction in the average field at >100$\,$K, results in a strengthening of the hydrogen bonds, consistent with the non-monotonic behaviour of absorption peak position around 100$\,$K seen in [Sup Mat Fig. 2a](#sup_figure_2).

# %% [markdown]
# ### Sup Mat.4 - Relative density changes between films prepared at different temperatures. <a class="anchor" id="sup_4"></a>

# %%
# read the data
df = pd.read_csv("./relative_densities.csv")
plt.style.use("./relative_densities.mplstyle")

fig, ax = plt.subplots(1, 1)
fig.set_size_inches(8, 4.5)

ax.errorbar(x=df['T (K)'], y=df['RD'], yerr=df['RD_err'], markersize=6,
            marker='o')

ax.set_ylabel("Relative Density", fontsize=18)
ax.set_xlabel("Ice Deposition Temperature (K)", fontsize=18)

plt.savefig("./Figure_3_sup_mat.png", dpi=500, bbox_inches="tight")

# %% [markdown]
# **Figure 3 - Sup Mat** <a class="anchor" id="sup_figure_3"></a>: _The relative density of water ices deposited as a function of temperature. Material was prepared as thin films with thicknesses of 350$\,$nm. Ices were deposited in an ultra-high vacuum chamber with a base pressure below 2E-10$\,$mbar via condensation onto a KBr substrate, from a background partial pressure of 1E-6$\,$mbar (1E-5$\,$mbar at 150$\,$K) of pure water vapour. Data were collected at the same temperature as deposition except for films deposited at 150$\,$K, where measurement occurred at 140$\,$K to limit desorption. The relative density was estimated by dividing the band area of the O-H stretching mode in the infrared photoabsorption spectrum of each individual ice, by the thickness of the deposited ice. Ice thicknesses were measured using a laser interferometry technique.[7](#sup_ref_7) The IR absorbance spectrum for each ice (not shown) was measured in transmission geometry. The error bars in the figure, are smaller than individual data points and were estimated by quantifying the standard deviation of the O-H stretching mode band area for several depositions at 40$\,$K. Relative densities are shown assuming that the cross section for absorbance is the same across the entire temperature range._
#
# These data show that ices increase in density as the deposition temperature rises until 120$\,$K. Above 120$\,$K, density remains constant. This represents the loss of porosity in amorphous ice films as deposition temperature is increased, until ices become crystalline with depositions above 120$\,$K. Density for crystalline films is constant with deposition temperature, indicating that crystalline films are not porous.

# %% [markdown]
# ### Sup Mat.5 - Executable paper. <a class="anchor" id="sup_5"></a>
#
# All material relevant to our analysis is available at https://github.com/cassidy-andrew/VUV_water_spont, which includes the code used to compare experiment and model. The code is written using the Python and Jupyter Notebook tools and is thus accessible in an open repository. We have copied the style adopted and explained in detail in [8](#sup_ref_8) for executable papers.

# %% [markdown]
# ### Sup Mat.6 - References. <a class="anchor" id="sup_6"></a>
#
# 1   M. J. Iedema, M. J. Dresser, D. L. Doering, J. B. Rowland, W. P. Hess, A. A. Tsekouras and J. P. Cowin, J. Phys. Chem. B, 1998, 102, 9203–9214.
#
# 2	C. Bu, J. Shi, U. Raut, E. H. Mitchell and R. A. Baragiola, J. Chem. Phys., 2015, 142, 134702.
#
# 3	R. Sagi, M. Akerman, S. Ramakrishnan and M. Asscher, J. Chem. Phys., 2020, 153, 144702.
#
# 4	I. Mata, E. Molins, I. Alkorta and E. Espinosa, The Journal of Chemical Physics, 2009, 130, 044104.
#
# 5	S. D. Fried and S. G. Boxer, Acc. Chem. Res., 2015, 48, 998–1006.
#
# 6	S. Rasoul Hashemi, M. R. S. McCoustra, H. J. Fraser and G. Nyman, Physical Chemistry Chemical Physics, 2022, 24, 12922–12925.
#
# 7	M. S. Westley, G. A. Baratta and R. A. Baragiola, J. Chem. Phys., 1998, 108, 3321–3326.
#
# 8	J. Lasser, Communications Physics, 2020, 3, 143.
